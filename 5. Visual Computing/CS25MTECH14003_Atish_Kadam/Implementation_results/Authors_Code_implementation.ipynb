# %% [markdown]
# ## Implementation and Reproduction of all results given by Author

# %% [markdown]
# ![WhatsApp Image 2026-03-28 at 7.53.57 PM.jpeg](data:image/jpeg;base64,...)

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e08dd5f2-201a-45f6-8810-ef9cea52a8b2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e08dd5f2-201a-45f6-8810-ef9cea52a8b2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !pip install ujson
# Out:
# ...
#   Using cached ujson-5.12.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (9.6 kB)
# Using cached ujson-5.12.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (57 kB)
# ...

# %%
pip install numpy==1.26.4 --force-reinstall
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 2.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 99.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# opencv-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# shap 0.51.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# tobler 0.13.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# jax 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# pytensor 2.38.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# ...

# %% [markdown]
# **CIFAR-10 with Alpha=0.1**

# %%
# !python main.py --niid --partition dir --rg 1 --num_client 100 --alpha 0.1 --clean_reg --dataset cifar10 --num_class 100 --modelseed 1 --pretrained
# Out:
# /content/main.py:79: UserWarning: You have chosen to seed training. This will turn on the CUDNN deterministic setting, which can slow down your training considerably! You may see unexpected behavior when restarting from checkpoints.
#   warnings.warn('You have chosen to seed training. '
# Use GPU: 0 for training
# => using pre-trained model 'resnet18'
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# ...

# %% [markdown]
# **CIFAR-10 with Alpha=0.05**

# %%
# !python main.py --niid --partition dir --rg 1 --num_client 100 --alpha 0.05 --clean_reg --dataset cifar10 --num_class 100 --modelseed 1 --pretrained
# Out:
# /content/main.py:79: UserWarning: You have chosen to seed training. This will turn on the CUDNN deterministic setting, which can slow down your training considerably! You may see unexpected behavior when restarting from checkpoints.
#   warnings.warn('You have chosen to seed training. '
# Use GPU: 0 for training
# => using pre-trained model 'resnet18'
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# ...

# %% [markdown]
# **CIFAR-10 with Shard=4**

# %%
# !python main.py --niid --partition dir --rg 1 --num_client 100 --alpha 0.1 --shred 4 --clean_reg --dataset cifar10 --num_class 100 --modelseed 1 --pretrained
# Out:
# /content/main.py:79: UserWarning: You have chosen to seed training. This will turn on the CUDNN deterministic setting, which can slow down your training considerably! You may see unexpected behavior when restarting from checkpoints.
#   warnings.warn('You have chosen to seed training. '
# Use GPU: 0 for training
# => using pre-trained model 'resnet18'
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# ...

# %% [markdown]
# **CIFAR-10 with Shard=2**

# %%
# !python main.py --niid --partition dir --rg 1 --num_client 100 --alpha 0.1 --shred 2 --clean_reg --dataset cifar10 --num_class 100 --modelseed 1 --pretrained
# Out:
# /content/main.py:79: UserWarning: You have chosen to seed training. This will turn on the CUDNN deterministic setting, which can slow down your training considerably! You may see unexpected behavior when restarting from checkpoints.
#   warnings.warn('You have chosen to seed training. '
# Use GPU: 0 for training
# => using pre-trained model 'resnet18'
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# ...

# %% [markdown]
# **CIFAR-100 with Alpha=0.1**

# %%
# !python main.py --niid --partition dir --rg 1 --num_client 100 --alpha 0.1 --clean_reg --dataset cifar100 --num_class 100 --modelseed 1 --pretrained
# Out:
# /content/main.py:79: UserWarning: You have chosen to seed training. This will turn on the CUDNN deterministic setting, which can slow down your training considerably! You may see unexpected behavior when restarting from checkpoints.
#   warnings.warn('You have chosen to seed training. '
# Use GPU: 0 for training
# => using pre-trained model 'resnet18'
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# ...

# %% [markdown]
# **CIFAR-100 with Alpha=0.05**

# %%
# !python main.py --niid --partition dir --rg 1 --num_client 100 --alpha 0.05 --clean_reg --dataset cifar100 --num_class 100 --modelseed 1 --pretrained
# Out:
# /content/main.py:79: UserWarning: You have chosen to seed training. This will turn on the CUDNN deterministic setting, which can slow down your training considerably! You may see unexpected behavior when restarting from checkpoints.
#   warnings.warn('You have chosen to seed training. '
# Use GPU: 0 for training
# => using pre-trained model 'resnet18'
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# ...

# %% [markdown]
# **CIFAR-100 Shard = 10**

# %%
# !python main.py --niid --partition dir --rg 1 --num_client 100 --alpha 0.1 --shred 10 --clean_reg --dataset cifar100 --num_class 100 --modelseed 1 --pretrained
# Out:
# /content/main.py:79: UserWarning: You have chosen to seed training. This will turn on the CUDNN deterministic setting, which can slow down your training considerably! You may see unexpected behavior when restarting from checkpoints.
#   warnings.warn('You have chosen to seed training. '
# Use GPU: 0 for training
# => using pre-trained model 'resnet18'
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# ...

# %% [markdown]
# **CIFAR-100 Shard = 5**

# %%
# !python main.py --niid --partition dir --rg 1 --num_client 100 --alpha 0.1 --shred 5 --clean_reg --dataset cifar100 --num_class 100 --modelseed 1 --pretrained
# Out:
# /content/main.py:79: UserWarning: You have chosen to seed training. This will turn on the CUDNN deterministic setting, which can slow down your training considerably! You may see unexpected behavior when restarting from checkpoints.
#   warnings.warn('You have chosen to seed training. '
# Use GPU: 0 for training
# => using pre-trained model 'resnet18'
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# ...

# %% [markdown]
# **Tinyimagenet with Alpha=0.1**

# %%
# !python main.py --niid --partition dir --rg 1 --num_client 100 --alpha 0.1 --clean_reg --dataset tinyimagenet --num_class 200 --modelseed 1 --pretrained
# Out:
# /content/main.py:79: UserWarning: You have chosen to seed training. This will turn on the CUDNN deterministic setting, which can slow down your training considerably! You may see unexpected behavior when restarting from checkpoints.
#   warnings.warn('You have chosen to seed training. '
# Use GPU: 0 for training
# => using pre-trained model 'resnet18'
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# ...

# %% [markdown]
# **Tinyimagenet with Alpha=0.05**

# %%
# !python main.py --niid --partition dir --rg 1 --num_client 100 --alpha 0.05 --clean_reg --dataset tinyimagenet --num_class 200 --modelseed 1 --pretrained
# Out:
# /content/main.py:79: UserWarning: You have chosen to seed training. This will turn on the CUDNN deterministic setting, which can slow down your training considerably! You may see unexpected behavior when restarting from checkpoints.
#   warnings.warn('You have chosen to seed training. '
# Use GPU: 0 for training
# => using pre-trained model 'resnet18'
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# ...

# %% [markdown]
# **Tiny-ImageNet with Shard = 10**

# %%
# !python main.py --niid --partition dir --rg 1 --num_client 100 --alpha 0.1 --shred 10 --clean_reg --dataset tinyimagenet --num_class 200 --modelseed 1 --pretrained
# Out:
# /content/main.py:79: UserWarning: You have chosen to seed training. This will turn on the CUDNN deterministic setting, which can slow down your training considerably! You may see unexpected behavior when restarting from checkpoints.
#   warnings.warn('You have chosen to seed training. '
# Use GPU: 0 for training
# => using pre-trained model 'resnet18'
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# ...

# %% [markdown]
# **Tiny-ImageNet with Shard = 5**

# %%
# !python main.py --niid --partition dir --rg 1 --num_client 100 --alpha 0.1 --shred 5 --clean_reg --dataset tinyimagenet --num_class 200 --modelseed 1 --pretrained
# Out:
# /content/main.py:79: UserWarning: You have chosen to seed training. This will turn on the CUDNN deterministic setting, which can slow down your training considerably! You may see unexpected behavior when restarting from checkpoints.
#   warnings.warn('You have chosen to seed training. '
# Use GPU: 0 for training
# => using pre-trained model 'resnet18'
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# ...

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **CIFAR-100 with No.of Cleints (K) = 500**

# %%
# !python main.py --niid --partition dir --rg 1 --num_client 500 --alpha 0.1 --clean_reg --dataset cifar100 --num_class 100 --modelseed 1 --pretrained
# Out:
# /content/main.py:79: UserWarning: You have chosen to seed training. This will turn on the CUDNN deterministic setting, which can slow down your training considerably! You may see unexpected behavior when restarting from checkpoints.
#   warnings.warn('You have chosen to seed training. '
# Use GPU: 0 for training
# => using pre-trained model 'resnet18'
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# ...

# %% [markdown]
# **CIFAR-100 with No.of Cleints (K) = 1000**

# %%
# !python main.py --niid --partition dir --rg 1 --num_client 1000 --alpha 0.1 --clean_reg --dataset cifar100 --num_class 100 --modelseed 1 --pretrained
# Out:
# /content/main.py:79: UserWarning: You have chosen to seed training. This will turn on the CUDNN deterministic setting, which can slow down your training considerably! You may see unexpected behavior when restarting from checkpoints.
#   warnings.warn('You have chosen to seed training. '
# Use GPU: 0 for training
# => using pre-trained model 'resnet18'
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# ...

# %% [markdown]
# **Tinyimagenet with No.of Cleints (K) = 500**

# %%
# !python main.py --niid --partition dir --rg 1 --num_client 500 --alpha 0.1 --clean_reg --dataset tinyimagenet --num_class 200 --modelseed 1 --pretrained
# Out:
# /content/main.py:79: UserWarning: You have chosen to seed training. This will turn on the CUDNN deterministic setting, which can slow down your training considerably! You may see unexpected behavior when restarting from checkpoints.
#   warnings.warn('You have chosen to seed training. '
# Use GPU: 0 for training
# => using pre-trained model 'resnet18'
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# ...

# %% [markdown]
# **Tinyimagenet with No.of Cleints (K) = 1000**

# %%
# !python main.py --niid --partition dir --rg 1 --num_client 1000 --alpha 0.1 --clean_reg --dataset tinyimagenet --num_class 200 --modelseed 1 --pretrained
# Out:
# /content/main.py:79: UserWarning: You have chosen to seed training. This will turn on the CUDNN deterministic setting, which can slow down your training considerably! You may see unexpected behavior when restarting from checkpoints.
#   warnings.warn('You have chosen to seed training. '
# Use GPU: 0 for training
# => using pre-trained model 'resnet18'
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# ...
