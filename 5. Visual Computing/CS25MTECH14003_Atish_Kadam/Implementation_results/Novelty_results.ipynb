# %%
from google.colab import files
uploaded = files.upload() # Select all your .py files
# Out:
#      <input type="file" id="files-a0b2cdab-d0e4-4a14-a877-84b74765f356" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a0b2cdab-d0e4-4a14-a877-84b74765f356">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !pip install ujson
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 4.8 MB/s eta 0:00:00
# ...

# %% [markdown]
# **CIFAR-10 with alpha=0.1**

# %%
# !python main.py \
  --dataset cifar10 \
  --num_clients 100 \
  --niid \
  --partition dir \
  --alpha 0.1 \
  --rg 1 \
  --clean_reg \
  --rank_r 32 \
  --pretrained \
  --gpu 0
# Out:
# Dataset: cifar10  |  num_classes: 10
# /content/main.py:102: UserWarning: Deterministic mode enabled
#   warnings.warn("Deterministic mode enabled")
# Using GPU: 0
# => using pre-trained model 'resnet18'
# 100% 170M/170M [00:05<00:00, 30.8MB/s]
#
# Training locally!
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:424: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   self.check_worker_number_rationality()
# ...

# %% [markdown]
# **CIFAR-10 with alpha=0.05**

# %%
# !python main.py \
  --dataset cifar10 \
  --num_clients 100 \
  --niid \
  --partition dir \
  --alpha 0.05 \
  --rg 1 \
  --clean_reg \
  --rank_r 32 \
  --pretrained \
  --gpu 0
# Out:
# Dataset: cifar10  |  num_classes: 10
# /content/main.py:102: UserWarning: Deterministic mode enabled
#   warnings.warn("Deterministic mode enabled")
# Using GPU: 0
# => using pre-trained model 'resnet18'
# Client data size does not meet the minimum requirement 10. Try allocating again for the 2-th time.
# Client data size does not meet the minimum requirement 10. Try allocating again for the 3-th time.
# Client data size does not meet the minimum requirement 10. Try allocating again for the 4-th time.
# Client data size does not meet the minimum requirement 10. Try allocating again for the 5-th time.
# Client data size does not meet the minimum requirement 10. Try allocating again for the 6-th time.
# Client data size does not meet the minimum requirement 10. Try allocating again for the 7-th time.
# Client data size does not meet the minimum requirement 10. Try allocating again for the 8-th time.
# ...

# %% [markdown]
# **CIFAR-10 with S=4**

# %%
# !python main.py \
  --dataset cifar10 \
  --num_clients 100 \
  --niid \
  --partition dir \
  --alpha 0.1 \
  --rg 1 \
  --clean_reg \
  --rank_r 32 \
  --pretrained \
  --shred 4 \
  --gpu 0
# Out:
# Dataset: cifar10  |  num_classes: 10
# /content/main.py:102: UserWarning: Deterministic mode enabled
#   warnings.warn("Deterministic mode enabled")
# Using GPU: 0
# => using pre-trained model 'resnet18'
#
# Training locally!
# Client 0 Train Acc: 100.00%
# Client 1 Train Acc: 100.00%
# Client 2 Train Acc: 100.00%
# Client 3 Train Acc: 100.00%
# Client 4 Train Acc: 100.00%
# Client 5 Train Acc: 100.00%
# Client 6 Train Acc: 100.00%
# Client 7 Train Acc: 100.00%
# Client 8 Train Acc: 100.00%
# Client 9 Train Acc: 100.00%
# Client 10 Train Acc: 100.00%
# Client 11 Train Acc: 100.00%
# Client 12 Train Acc: 100.00%
# Client 13 Train Acc: 100.00%
# Client 14 Train Acc: 100.00%
# Client 15 Train Acc: 99.68%
# Client 16 Train Acc: 100.00%
# Client 17 Train Acc: 100.00%
# Client 18 Train Acc: 100.00%
# Client 19 Train Acc: 100.00%
# Client 20 Train Acc: 100.00%
# Client 21 Train Acc: 100.00%
# Client 22 Train Acc: 100.00%
# Client 23 Train Acc: 100.00%
# Client 24 Train Acc: 100.00%
# ...

# %% [markdown]
# **CIFAR-10 with S=2**

# %%
# !python main.py \
  --dataset cifar10 \
  --num_clients 100 \
  --niid \
  --partition dir \
  --alpha 0.1 \
  --rg 1 \
  --clean_reg \
  --rank_r 32 \
  --pretrained \
  --shred 2 \
  --gpu 0
# Out:
# Dataset: cifar10  |  num_classes: 10
# /content/main.py:102: UserWarning: Deterministic mode enabled
#   warnings.warn("Deterministic mode enabled")
# Using GPU: 0
# => using pre-trained model 'resnet18'
#
# Training locally!
# Client 0 Train Acc: 100.00%
# Client 1 Train Acc: 99.81%
# Client 2 Train Acc: 100.00%
# Client 3 Train Acc: 99.78%
# Client 4 Train Acc: 100.00%
# Client 5 Train Acc: 97.82%
# Client 6 Train Acc: 100.00%
# Client 7 Train Acc: 100.00%
# Client 8 Train Acc: 100.00%
# Client 9 Train Acc: 100.00%
# Client 10 Train Acc: 100.00%
# Client 11 Train Acc: 100.00%
# Client 12 Train Acc: 100.00%
# Client 13 Train Acc: 99.89%
# Client 14 Train Acc: 100.00%
# Client 15 Train Acc: 100.00%
# Client 16 Train Acc: 97.39%
# Client 17 Train Acc: 100.00%
# Client 18 Train Acc: 100.00%
# Client 19 Train Acc: 100.00%
# Client 20 Train Acc: 100.00%
# Client 21 Train Acc: 100.00%
# Client 22 Train Acc: 100.00%
# Client 23 Train Acc: 98.41%
# Client 24 Train Acc: 99.72%
# ...

# %% [markdown]
# **CIFAR-100 with alpha=0.1**

# %%
# !python main.py \
  --dataset cifar100 \
  --num_clients 100 \
  --niid \
  --partition dir \
  --alpha 0.1 \
  --rg 1 \
  --clean_reg \
  --rank_r 32 \
  --pretrained \
  --gpu 0
# Out:
# Dataset: cifar100  |  num_classes: 100
# /content/main.py:102: UserWarning: Deterministic mode enabled
#   warnings.warn("Deterministic mode enabled")
# Using GPU: 0
# => using pre-trained model 'resnet18'
# 100% 169M/169M [00:03<00:00, 47.6MB/s]
#
# Training locally!
# Client 0 Train Acc: 100.00%
# Client 1 Train Acc: 100.00%
# Client 2 Train Acc: 100.00%
# Client 3 Train Acc: 99.80%
# Client 4 Train Acc: 100.00%
# Client 5 Train Acc: 99.81%
# Client 6 Train Acc: 100.00%
# Client 7 Train Acc: 99.43%
# Client 8 Train Acc: 100.00%
# Client 9 Train Acc: 98.87%
# Client 10 Train Acc: 98.14%
# Client 11 Train Acc: 100.00%
# Client 12 Train Acc: 99.73%
# Client 13 Train Acc: 99.58%
# Client 14 Train Acc: 100.00%
# Client 15 Train Acc: 100.00%
# Client 16 Train Acc: 100.00%
# Client 17 Train Acc: 100.00%
# Client 18 Train Acc: 99.76%
# Client 19 Train Acc: 99.52%
# Client 20 Train Acc: 100.00%
# Client 21 Train Acc: 99.45%
# Client 22 Train Acc: 100.00%
# Client 23 Train Acc: 99.61%
# ...

# %% [markdown]
# **CIFAR-100 with alpha=0.05**

# %%
# !python main.py \
  --dataset cifar100 \
  --num_clients 100 \
  --niid \
  --partition dir \
  --alpha 0.05 \
  --rg 1 \
  --clean_reg \
  --rank_r 32 \
  --pretrained \
  --gpu 0
# Out:
# Dataset: cifar100  |  num_classes: 100
# /content/main.py:102: UserWarning: Deterministic mode enabled
#   warnings.warn("Deterministic mode enabled")
# Using GPU: 0
# => using pre-trained model 'resnet18'
#
# Training locally!
# Client 0 Train Acc: 100.00%
# Client 1 Train Acc: 100.00%
# Client 2 Train Acc: 100.00%
# Client 3 Train Acc: 100.00%
# Client 4 Train Acc: 100.00%
# Client 5 Train Acc: 100.00%
# Client 6 Train Acc: 100.00%
# Client 7 Train Acc: 100.00%
# Client 8 Train Acc: 100.00%
# Client 9 Train Acc: 99.83%
# Client 10 Train Acc: 100.00%
# Client 11 Train Acc: 100.00%
# Client 12 Train Acc: 100.00%
# Client 13 Train Acc: 100.00%
# Client 14 Train Acc: 100.00%
# Client 15 Train Acc: 100.00%
# Client 16 Train Acc: 100.00%
# Client 17 Train Acc: 100.00%
# Client 18 Train Acc: 100.00%
# Client 19 Train Acc: 100.00%
# Client 20 Train Acc: 100.00%
# Client 21 Train Acc: 99.84%
# Client 22 Train Acc: 100.00%
# Client 23 Train Acc: 100.00%
# Client 24 Train Acc: 100.00%
# ...

# %% [markdown]
# **CIFAR-100 with s=10**

# %%
# !python main.py \
  --dataset cifar100 \
  --num_clients 100 \
  --niid \
  --partition dir \
  --alpha 0.1 \
  --rg 1 \
  --clean_reg \
  --rank_r 32 \
  --pretrained \
  --shred 10 \
  --gpu 0
# Out:
# Dataset: cifar100  |  num_classes: 100
# /content/main.py:102: UserWarning: Deterministic mode enabled
#   warnings.warn("Deterministic mode enabled")
# Using GPU: 0
# => using pre-trained model 'resnet18'
#
# Training locally!
# Client 0 Train Acc: 100.00%
# Client 1 Train Acc: 100.00%
# Client 2 Train Acc: 100.00%
# Client 3 Train Acc: 99.34%
# Client 4 Train Acc: 100.00%
# Client 5 Train Acc: 99.27%
# Client 6 Train Acc: 99.82%
# Client 7 Train Acc: 98.96%
# Client 8 Train Acc: 100.00%
# Client 9 Train Acc: 99.38%
# Client 10 Train Acc: 98.14%
# Client 11 Train Acc: 99.53%
# Client 12 Train Acc: 99.58%
# Client 13 Train Acc: 99.78%
# Client 14 Train Acc: 100.00%
# Client 15 Train Acc: 100.00%
# Client 16 Train Acc: 100.00%
# Client 17 Train Acc: 99.63%
# Client 18 Train Acc: 99.51%
# Client 19 Train Acc: 99.25%
# Client 20 Train Acc: 100.00%
# Client 21 Train Acc: 99.23%
# Client 22 Train Acc: 100.00%
# Client 23 Train Acc: 98.28%
# Client 24 Train Acc: 100.00%
# ...

# %% [markdown]
# **CIFAR-100 with s=5**

# %%
# !python main.py \
  --dataset cifar100 \
  --num_clients 100 \
  --niid \
  --partition dir \
  --alpha 0.1 \
  --rg 1 \
  --clean_reg \
  --rank_r 32 \
  --pretrained \
  --shred 5 \
  --gpu 0
# Out:
# Dataset: cifar100  |  num_classes: 100
# /content/main.py:102: UserWarning: Deterministic mode enabled
#   warnings.warn("Deterministic mode enabled")
# Using GPU: 0
# => using pre-trained model 'resnet18'
#
# Training locally!
# Client 0 Train Acc: 100.00%
# Client 1 Train Acc: 100.00%
# Client 2 Train Acc: 100.00%
# Client 3 Train Acc: 99.34%
# Client 4 Train Acc: 100.00%
# Client 5 Train Acc: 99.27%
# Client 6 Train Acc: 99.82%
# Client 7 Train Acc: 98.96%
# Client 8 Train Acc: 100.00%
# Client 9 Train Acc: 99.38%
# Client 10 Train Acc: 98.14%
# Client 11 Train Acc: 99.53%
# Client 12 Train Acc: 99.58%
# Client 13 Train Acc: 99.78%
# Client 14 Train Acc: 100.00%
# Client 15 Train Acc: 100.00%
# Client 16 Train Acc: 100.00%
# Client 17 Train Acc: 99.63%
# Client 18 Train Acc: 99.51%
# Client 19 Train Acc: 99.25%
# Client 20 Train Acc: 100.00%
# Client 21 Train Acc: 99.23%
# Client 22 Train Acc: 100.00%
# Client 23 Train Acc: 98.28%
# Client 24 Train Acc: 100.00%
# ...

# %% [markdown]
# **Tinyimagenet with Alpha = 0.1**

# %%
# !python main.py \
  --dataset tinyimagenet \
  --num_clients 100 \
  --niid \
  --partition dir \
  --alpha 0.1 \
  --rg 1 \
  --clean_reg \
  --rank_r 32 \
  --pretrained \
  --gpu 0
# Out:
# Dataset: tinyimagenet  |  num_classes: 200
# /content/main.py:102: UserWarning: Deterministic mode enabled
#   warnings.warn("Deterministic mode enabled")
# Using GPU: 0
# => using pre-trained model 'resnet18'
#
# Training locally!
# Client 0 Train Acc: 97.25%
# Client 1 Train Acc: 94.62%
# Client 2 Train Acc: 91.64%
# Client 3 Train Acc: 93.85%
# Client 4 Train Acc: 91.35%
# Client 5 Train Acc: 91.89%
# Client 6 Train Acc: 94.24%
# Client 7 Train Acc: 95.21%
# Client 8 Train Acc: 92.78%
# Client 9 Train Acc: 92.46%
# Client 10 Train Acc: 92.69%
# Client 11 Train Acc: 93.94%
# Client 12 Train Acc: 92.95%
# Client 13 Train Acc: 91.68%
# Client 14 Train Acc: 94.55%
# Client 15 Train Acc: 94.33%
# Client 16 Train Acc: 94.76%
# Client 17 Train Acc: 93.09%
# Client 18 Train Acc: 92.04%
# Client 19 Train Acc: 92.47%
# Client 20 Train Acc: 94.76%
# Client 21 Train Acc: 94.93%
# Client 22 Train Acc: 94.18%
# Client 23 Train Acc: 89.86%
# Client 24 Train Acc: 91.93%
# ...

# %% [markdown]
# **Tinyimagenet with Alpha = 0.05**

# %%
# !python main.py \
  --dataset tinyimagenet \
  --num_clients 100 \
  --niid \
  --partition dir \
  --alpha 0.05 \
  --rg 1 \
  --clean_reg \
  --rank_r 32 \
  --pretrained \
  --gpu 0
# Out:
# Dataset: tinyimagenet  |  num_classes: 200
# /content/main.py:102: UserWarning: Deterministic mode enabled
#   warnings.warn("Deterministic mode enabled")
# Using GPU: 0
# => using pre-trained model 'resnet18'
#
# Training locally!
# Client 0 Train Acc: 99.01%
# Client 1 Train Acc: 99.04%
# Client 2 Train Acc: 97.91%
# Client 3 Train Acc: 98.39%
# Client 4 Train Acc: 98.40%
# Client 5 Train Acc: 99.10%
# Client 6 Train Acc: 99.63%
# Client 7 Train Acc: 99.72%
# Client 8 Train Acc: 99.28%
# Client 9 Train Acc: 97.77%
# Client 10 Train Acc: 100.00%
# Client 11 Train Acc: 98.11%
# Client 12 Train Acc: 99.19%
# Client 13 Train Acc: 96.58%
# Client 14 Train Acc: 98.29%
# Client 15 Train Acc: 97.95%
# Client 16 Train Acc: 96.50%
# Client 17 Train Acc: 98.72%
# Client 18 Train Acc: 98.28%
# Client 19 Train Acc: 98.85%
# Client 20 Train Acc: 98.49%
# Client 21 Train Acc: 98.93%
# Client 22 Train Acc: 98.79%
# Client 23 Train Acc: 96.31%
# Client 24 Train Acc: 97.02%
# ...

# %% [markdown]
# **Tinyimagenet with s=10**

# %%
# !python main.py \
  --dataset tinyimagenet \
  --num_clients 100 \
  --niid \
  --partition dir \
  --alpha 0.1 \
  --rg 1 \
  --clean_reg \
  --rank_r 32 \
  --shred 10 \
  --pretrained \
  --gpu 0
# Out:
# Dataset: tinyimagenet  |  num_classes: 200
# /content/main.py:102: UserWarning: Deterministic mode enabled
#   warnings.warn("Deterministic mode enabled")
# Using GPU: 0
# => using pre-trained model 'resnet18'
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100% 44.7M/44.7M [00:00<00:00, 204MB/s]
# ...
# Extracting Tiny ImageNet...
# Restructuring val/ folder...
#
# Training locally!
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:424: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   self.check_worker_number_rationality()
# ...

# %% [markdown]
# **Tinyimagenet with s=5**

# %%
# !python main.py \
  --dataset tinyimagenet \
  --num_clients 100 \
  --niid \
  --partition dir \
  --alpha 0.1 \
  --rg 1 \
  --clean_reg \
  --rank_r 32 \
  --pretrained \
  --shred 5 \
  --gpu 0
# Out:
# Dataset: tinyimagenet  |  num_classes: 200
# /content/main.py:102: UserWarning: Deterministic mode enabled
#   warnings.warn("Deterministic mode enabled")
# Using GPU: 0
# => using pre-trained model 'resnet18'
#
# Training locally!
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:424: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   self.check_worker_number_rationality()
# ...

# %% [markdown]
# **CIFAR-100 with K = 500**

# %%
# !python main.py \
  --dataset cifar100 \
  --num_clients 500 \
  --niid \
  --partition dir \
  --alpha 0.1 \
  --rg 1 \
  --clean_reg \
  --rank_r 32 \
  --pretrained \
  --gpu 0
# Out:
# Dataset: cifar100  |  num_classes: 100
# /content/main.py:102: UserWarning: Deterministic mode enabled
#   warnings.warn("Deterministic mode enabled")
# Using GPU: 0
# => using pre-trained model 'resnet18'
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100% 44.7M/44.7M [00:00<00:00, 198MB/s]
# 100% 169M/169M [00:04<00:00, 41.1MB/s]
#
# Training locally!
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:424: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   self.check_worker_number_rationality()
# ...

# %% [markdown]
# **CIFAR-100 with K = 1000**

# %%
# !python main.py \
  --dataset cifar100 \
  --num_clients 1000 \
  --niid \
  --partition dir \
  --alpha 0.1 \
  --rg 1 \
  --clean_reg \
  --rank_r 32 \
  --pretrained \
  --gpu 0
# Out:
# Dataset: cifar100  |  num_classes: 100
# /content/main.py:102: UserWarning: Deterministic mode enabled
#   warnings.warn("Deterministic mode enabled")
# Using GPU: 0
# => using pre-trained model 'resnet18'
# 100% 169M/169M [00:13<00:00, 12.5MB/s]
#
# Training locally!
# Client 0 Train Acc: 100.00%
# Client 1 Train Acc: 100.00%
# Client 2 Train Acc: 100.00%
# Client 3 Train Acc: 100.00%
# Client 4 Train Acc: 100.00%
# Client 5 Train Acc: 100.00%
# Client 6 Train Acc: 100.00%
# Client 7 Train Acc: 100.00%
# Client 8 Train Acc: 100.00%
# Client 9 Train Acc: 100.00%
# Client 10 Train Acc: 100.00%
# Client 11 Train Acc: 100.00%
# Client 12 Train Acc: 100.00%
# Client 13 Train Acc: 100.00%
# Client 14 Train Acc: 100.00%
# Client 15 Train Acc: 100.00%
# Client 16 Train Acc: 100.00%
# Client 17 Train Acc: 100.00%
# Client 18 Train Acc: 100.00%
# Client 19 Train Acc: 100.00%
# Client 20 Train Acc: 100.00%
# Client 21 Train Acc: 100.00%
# Client 22 Train Acc: 100.00%
# ...

# %% [markdown]
# **Tiny-Imagenet with K = 500**

# %%
# !python main.py \
  --dataset tinyimagenet \
  --num_clients 500 \
  --niid \
  --partition dir \
  --alpha 0.1 \
  --rg 1 \
  --clean_reg \
  --rank_r 32 \
  --pretrained \
  --gpu 0
# Out:
# Dataset: tinyimagenet  |  num_classes: 200
# /content/main.py:102: UserWarning: Deterministic mode enabled
#   warnings.warn("Deterministic mode enabled")
# Using GPU: 0
# => using pre-trained model 'resnet18'
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100% 44.7M/44.7M [00:00<00:00, 208MB/s]
# ...
# Extracting Tiny ImageNet...
# Restructuring val/ folder...
#
# Training locally!
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:424: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   self.check_worker_number_rationality()
# ...

# %% [markdown]
# **Tiny-Imagenet with K = 1000**

# %%
# !python main.py \
  --dataset tinyimagenet \
  --num_clients 1000 \
  --niid \
  --partition dir \
  --alpha 0.1 \
  --rg 1 \
  --clean_reg \
  --rank_r 32 \
  --pretrained \
  --gpu 0
# Out:
# Dataset: tinyimagenet  |  num_classes: 200
# /content/main.py:102: UserWarning: Deterministic mode enabled
#   warnings.warn("Deterministic mode enabled")
# Using GPU: 0
# => using pre-trained model 'resnet18'
# ...
# Extracting Tiny ImageNet...
# Restructuring val/ folder...
#
# Training locally!
# Client 0 Train Acc: 100.00%
# Client 1 Train Acc: 100.00%
# Client 2 Train Acc: 100.00%
# Client 3 Train Acc: 100.00%
# Client 4 Train Acc: 100.00%
# Client 5 Train Acc: 100.00%
# Client 6 Train Acc: 100.00%
# Client 7 Train Acc: 100.00%
# Client 8 Train Acc: 100.00%
# Client 9 Train Acc: 99.00%
# Client 10 Train Acc: 100.00%
# Client 11 Train Acc: 100.00%
# Client 12 Train Acc: 100.00%
# Client 13 Train Acc: 100.00%
# Client 14 Train Acc: 100.00%
# Client 15 Train Acc: 100.00%
# Client 16 Train Acc: 100.00%
# Client 17 Train Acc: 100.00%
# Client 18 Train Acc: 100.00%
# Client 19 Train Acc: 100.00%
# Client 20 Train Acc: 99.03%
# Client 21 Train Acc: 100.00%
# Client 22 Train Acc: 100.00%
# ...
